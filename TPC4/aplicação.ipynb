# %%
import random

print (" Bem vindo ao menu! Escolha o que deseja fazer")
print (""" Menu:\n1)Criar Lista\n2)Ler Lista\n3)Soma\n4)Média\n5)Maior
6)Menor\n7)Ordenada por ordem crescente\n8)Ordenada por ordem decrescente
9)Procurar um elemento\n0)Sair""")

lista = [1 , 5, 8, 15, 66]
n= int(input("Introduza um número de 0 a 9 para prosseguir."))


while n != 0:
    if n == 1:
        lista.clear()
        N = int(input("Introduza o número de elementos pretendidos"))
        lista = []
        while len (lista) < N:
            num = random.randrange (1 , 101)
            lista.append (num)
        print (lista)
        print (""" Menu:\n1)Criar Lista\n2)Ler Lista\n3)Soma\n4)Média\n5)Maior
6)Menor\n7)Ordenada por ordem crescente\n8)Ordenada por ordem decrescente
9)Procurar um elemento\n0)Sair""")
        n = int(input("Introduza o número da próxima funcionalidade"))
    elif n == 2:
        lista.clear ()
        lista = []
        N= int(input("Introduza quantos elementos deseja na lista"))
        x = 0
        while x < N:
                l = int(input("Introduza os núemros que deseja que a lista tenha"))
                lista.append(l)
                x = x + 1
        print (lista)
        print (""" Menu:\n1)Criar Lista\n2)Ler Lista\n3)Soma\n4)Média\n5)Maior
6)Menor\n7)Ordenada por ordem crescente\n8)Ordenada por ordem decrescente
9)Procurar um elemento\n0)Sair""")
        n = int(input("Introduza o número da próxima funcionalidade"))
    elif n == 3:
        soma = 0
        for e in lista:
            soma = soma + e
        print ("A soma é:" , soma)
        print (""" Menu:\n1)Criar Lista\n2)Ler Lista\n3)Soma\n4)Média\n5)Maior
6)Menor\n7)Ordenada por ordem crescente\n8)Ordenada por ordem decrescente
9)Procurar um elemento\n0)Sair""")
        n = int(input("Introduza o número da próxima funcionalidade"))
    elif n == 4:
        soma = 0
        x = 0
        for e in lista:
            soma = soma + e
            x = x + 1
        media = soma / x
        print ("A média é:" , media)
        print (""" Menu:\n1)Criar Lista\n2)Ler Lista\n3)Soma\n4)Média\n5)Maior
6)Menor\n7)Ordenada por ordem crescente\n8)Ordenada por ordem decrescente
9)Procurar um elemento\n0)Sair""")
        n = int(input("Introduza o número da próxima funcionalidade"))
    elif n == 5:
        maior = 0
        for e in lista:
            if e > maior:
                maior = e
        print ("o maior é:" , maior)
        print (""" Menu:\n1)Criar Lista\n2)Ler Lista\n3)Soma\n4)Média\n5)Maior
6)Menor\n7)Ordenada por ordem crescente\n8)Ordenada por ordem decrescente
9)Procurar um elemento\n0)Sair""")
        n = int(input("Introduza o número da próxima funcionalidade"))
    elif n == 6:
        menor = lista[0]
        for e in lista:
            if e < menor:
                menor = e
        print ("O menor é:" , menor)
        print (""" Menu:\n1)Criar Lista\n2)Ler Lista\n3)Soma\n4)Média\n5)Maior
6)Menor\n7)Ordenada por ordem crescente\n8)Ordenada por ordem decrescente
9)Procurar um elemento\n0)Sair""")
        n = int(input("Introduza o número da próxima funcionalidade"))
    elif n == 7:
        lista1 = lista.copy ()
        lista1.sort ()
        if lista == lista1:
            print ("Sim!")
        else:
            print ("Não!")
        print (""" Menu:\n1)Criar Lista\n2)Ler Lista\n3)Soma\n4)Média\n5)Maior
6)Menor\n7)Ordenada por ordem crescente\n8)Ordenada por ordem decrescente
9)Procurar um elemento\n0)Sair""")
        n = int(input("Introduza o número da próxima funcionalidade"))
    elif n == 8:
        lista2 = lista.copy ()
        lista2.sort ()
        lista2.reverse ()
        if lista == lista2:
            print ("Sim!")
        else:
            print ("Não!")
        print (""" Menu:\n1)Criar Lista\n2)Ler Lista\n3)Soma\n4)Média\n5)Maior
6)Menor\n7)Ordenada por ordem crescente\n8)Ordenada por ordem decrescente
9)Procurar um elemento\n0)Sair""")
        n = int(input("Introduza o número da próxima funcionalidade"))
    elif n == 9:
        h = int(input("Introduza o número que quer descobrir"))
        posição = lista.index (h)
        if h in lista:
            print (posição , h)
        else:
            print ("-1")
        print (""" Menu:\n1)Criar Lista\n2)Ler Lista\n3)Soma\n4)Média\n5)Maior
6)Menor\n7)Ordenada por ordem crescente\n8)Ordenada por ordem decrescente
9)Procurar um elemento\n0)Sair""")
        n = int(input("Introduza o número da próxima funcionalidade"))

if n == 0:
    print ("   A aplicação fechou. Volte sempre!")
